# %%
# Leakage Mapping for Plastic Waste

## Mapping concept for the state of plastic waste abundance in the city level 

**Initiated form the work under CounterMEASURE, elaborated with the Material Flow Analysis concepts**

# %%
## Libraries 

**sys for path changing withing the ArcGIS pro environment, under the Model Builder improvements**
**arcpy for working under the python in ArcGIS**

import sys 
sys.path.append(r"C:\Users\april\AppData\Local\Temp\_")

import arcpy 
from arcpy import env #for directed the workspace in local, alternative in sys
from arcpy.ia import *
from arcpy.sa import *

def LeakageMapping():
    arcpy.env.overwriteOutput = False
    
    arcpy.CheckOutExtension("spatial")
    arcpy.CheckOutExtension("ImageAnalyst")
    arcpy.CheckPutExtension("3D")
pass

# %%
# Input the data parameters

def AnnualHotspot():
    ## Define the built tolbox (default)
    arcpy.ImportToolbox(r"C:\program files\arcgis\pro\Resources\ArcToolbox\toolboxes\Analysis Tools.tbx")
    
    ## Default naming in three alphabets code for the city
    area = *'YGN'* # added soon
    
    ## Population
    _1_Population_Density = arcpy.Raster("1_Population_Density")
    FuzzyMembership("1_Population_Density", {FuzzyLinear({0},{1})}, {"NONE"})
    
    ## LULC
    _2_LULC = arcpy.Raster("2_LULC")
    FuzzyMembership("2_LULC", {FuzzyLinear({0},{1})}, {"NONE"})
    
    ## Building Footprints
    _3a_Building_Industrial = "3a_Building_Industrial"
    FuzzyMembership("3a_Building_Industrial", {FuzzyMSLarge({1},{1})}, {"NONE"})
    _3_Building_Footprints = "3_Building_Footprints"
    FuzzyMembership("3_Building_Footprints", {FuzzyMSLarge({1},{1})}, {"NONE"})
    
    ## Slum Area
    _4_Slum = arcpy.Raster("4_Slum")
    FuzzyMembership("4_Slum", {FuzzyLarge({33.914463043213},{5})}, {"NONE"}) # midpint and spread through 5 cells
    
    ## Road Networks
    _6_Road_Networks = "6_Road_Networks"
    FuzzyMembership("4_Slum", {FuzzySmall({0.06792501360177994},{5})}, {"NONE"})
    
    ## Infrastructure
    _7_Infrastructure_POIs = "7_Infrastructure_POIs"
    Membership_type = [{"LARGE", 1423768, 5}]
    
    ## Nightlight Imagery
    _8_NLRS = arcpy.Raster("8_NLRS")
    Membership type = [{"LINEAR", 0, 1}]
    
    ## Plastic Waste Generation
    Population_Building = arcpy.analysis.Intersect("3_BUilding_Footprints", "1_Population_Density")
    Membership_type_4_ = [["MSLARGE", 1, 1]]
    
    _4_Slum_YGN_tif_2_ = arcpy.Raster("Raw Static Data\\4_Slum_YGN.tif")
    
    _10_Waste_Collection_YGN_2_ = "Raw Static Data\\10_Waste_Collection_YGN"
    Distance_value_or_field_ = "1000 Meters"
    Membership_type_5_ = [["MSLARGE", 1, 1]]
    Overlay_type = "AND"
    Output_cell_size = "30"
    
    ## Traffic Data
    Traffic16_2_Spatial_Join_Road_YGN = "Traffic16_2_Spatial_Join_Road_YGN"
    Membership_type_11_ = [["MSSMALL", 1, 1]]
    
    ## Mobile-app Survey Results
    Artificial_Barrier = "Artificial Barrier"
    Population_field_2_ = "how_many_2"
    Membership_type_13_ = [["MSLARGE", 1, 1]]
    
    Littering_Spot = "Littering Spot"
    Population_field_3_ = "volume"
    Membership_type_14_ = [["LARGE", 43677.125, 5]]
    
    Uncontrol_Dumpsite = "Uncontrol Dumpsite"
    Population_field_4_ = "volume"
    Membership_type_15_ = [["MSLARGE", 1, 1]]
    
    Overlay_type_2_ = "AND"
    Output_cell_size_2_ = "30"
    
    ## River Network
    River_Network_3_Merge_YGN = "River_Network_3_Merge_YGN"
    Membership_type_12_ = [["SMALL", 0.026510169729590416, 5]]
    
    ## Digital Elevation Model
    SRTM_10_Clip_VillageTractsSq_YGN = arcpy.Raster("SRTM_10_Clip_VillageTractsSq_YGN")
    Membership_type_16_ = [["SMALL", 16.706859588623047, 5]]
    
    ## Rainfall Rate
    chirps_v2_0_2022_0102_tiff = arcpy.Raster("chirps-v2.0.2022.0102.tiff")
    YCDC_Bounding_Box = "YCDC Bounding Box"
    
    chirps_v2_0_2022_0203_tiff = arcpy.Raster("chirps-v2.0.2022.0203.tiff")
    chirps_v2_0_2022_0304_tiff = arcpy.Raster("chirps-v2.0.2022.0304.tiff")
    chirps_v2_0_2022_0405_tiff = arcpy.Raster("chirps-v2.0.2022.0405.tiff")
    chirps_v2_0_2022_0506_tiff = arcpy.Raster("chirps-v2.0.2022.0506.tiff")
    chirps_v2_0_2022_0607_tiff = arcpy.Raster("chirps-v2.0.2022.0607.tiff")
    chirps_v2_0_2022_0708_tiff = arcpy.Raster("chirps-v2.0.2022.0708.tiff")
    chirps_v2_0_2022_0809_tiff = arcpy.Raster("chirps-v2.0.2022.0809.tiff")
    chirps_v2_0_2022_0910_tiff = arcpy.Raster("chirps-v2.0.2022.0910.tiff")
    chirps_v2_0_2022_1011_tiff = arcpy.Raster("chirps-v2.0.2022.1011.tiff")
    chirps_v2_0_2022_1112_tiff = arcpy.Raster("chirps-v2.0.2022.1112.tiff")
    
    Statistics_Type_2_ = "MEAN"
    Output_Cell_Size_5_ = "4.60161077875481E-04 4.60161077875481E-04"
    Membership_type_17_ = [["LARGE", 5251.55615234375, 5]]
    
    ## Flood Record
    FloodDecade_3_RasterLayer_Band1_YGN = arcpy.Raster("FloodDecade_3_RasterLayer_Band1_YGN")
    FloodPost_3_Clip_YGN = "FloodPost_3_Clip_YGN"
    Value_field = "Binary"
    Cellsize = "0.0002694945852358551"
    
    ## Erosivity
    SoilErosivity_1_Clip_Raster_YGN = arcpy.Raster("SoilErosivity_1_Clip_Raster_YGN")
    Membership_type_18_ = [["LARGE", 5876.93994140625, 5]]
    
    ## Drainage Morphometry
    Morphometric_3_Weighted_Clip_YCDC_YGN = arcpy.Raster("Morphometric_3_Weighted_Clip_YCDC_YGN")
    Membership_type_19_ = [["LARGE", 10.950000286102295, 5]]
    
    Overlay_type_3_ = "AND"
    
    Dataset_Static_5_VT_Boundaries_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Dataset_Static_5_VT_Boundaries_YGN"
    Zone_Field = "ST"
    Statistics_Type = "SUM"
    Population_field = "GRID_CODE"
    Output_cell_size_3_ = "30"
    Field = "Value"
    
    Field_Name_Existing_or_New_ = "waste_gen"
    Expression = "((!grid_code!*(0.5))*0.2)"
    
    FuzzyM_15_Drainage_Morphometry_YGN_2_ = arcpy.Raster("D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\FuzzyM_15_Drainage_Morphometry_YGN")
    
    River_Network_3_Merge_YGN_2_ = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\River_Network_3_Merge_YGN"
    Use_Input_Features_for_Clipping_Geometry = True
    Zone_Field_2_ = "feature"
    Statistics_Type_3_ = "SUM"
    Distances = [100, 300, 500]
    Distance_Unit = "Meters"
    
    Field_2_ = "distance"
    Output_cell_size_6_ = "0.00027027027027027"
    Membership_type_20_ = [["SMALL", 300, 5]]
    
    Zone_Field_3_ = "feature"
    Statistics_Type_4_ = "SUM"
    Population_field_5_ = "GRID_CODE"
    Output_cell_size_7_ = "30"
    
    Field = "Value"
    Field_Name_Existing_or_New_ = "waste_gen"
    Expression = "((!grid_code!*(0.5))*0.2)"
    FuzzyM_15_Drainage_Morphometry_YGN_2_ = arcpy.Raster("D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\FuzzyM_15_Drainage_Morphometry_YGN")
    River_Network_3_Merge_YGN_2_ = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\River_Network_3_Merge_YGN"
    Use_Input_Features_for_Clipping_Geometry = True
    Zone_Field_2_ = "feature"
    Statistics_Type_3_ = "SUM"
    Distances = [100, 300, 500]
    Distance_Unit = "Meters"
    Field_2_ = "distance"
    Output_cell_size_6_ = "0.00027027027027027"
    Membership_type_20_ = [["SMALL", 300, 5]]
    Zone_Field_3_ = "feature"
    Statistics_Type_4_ = "SUM"
    Population_field_5_ = "GRID_CODE"
    Output_cell_size_7_ = "30"
    Waterway_OSM_YGN = "Waterway_OSM_YGN"
    Join_Operation = "JOIN_ONE_TO_MANY"
    Field_Map = "full_id \"full_id\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,full_id,0,254;osm_id \"osm_id\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,osm_id,0,254;osm_type \"osm_type\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,osm_type,0,254;waterway \"waterway\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,waterway,0,254;source_nam \"source_nam\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,source_nam,0,254;GNS_id \"GNS_id\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,GNS_id,0,254;waterway_t \"waterway_t\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,waterway_t,0,254;water_supp \"water_supp\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,water_supp,0,254;usage \"usage\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,usage,0,254;waterway_2 \"waterway_2\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,waterway_2,0,254;irrigated \"irrigated\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,irrigated,0,254;irrigation \"irrigation\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,irrigation,0,254;motor_vehi \"motor_vehi\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,motor_vehi,0,254;descriptio \"descriptio\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,descriptio,0,254;route \"route\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,route,0,254;oneway \"oneway\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,oneway,0,254;power \"power\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,power,0,254;surface \"surface\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,surface,0,254;name_ru \"name_ru\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,name_ru,0,254;alt_name \"alt_name\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,alt_name,0,254;service \"service\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,service,0,254;highway \"highway\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,highway,0,254;width \"width\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,width,0,254;tunnel \"tunnel\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,tunnel,0,254;wikidata \"wikidata\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,wikidata,0,254;name_zh \"name_zh\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,name_zh,0,254;name_kn \"name_kn\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,name_kn,0,254;name_hi \"name_hi\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,name_hi,0,254;alt_name_e \"alt_name_e\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,alt_name_e,0,254;wikipedia \"wikipedia\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,wikipedia,0,254;start_date \"start_date\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,start_date,0,254;int_name \"int_name\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,int_name,0,254;tidal \"tidal\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,tidal,0,254;name_my \"name_my\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,name_my,0,254;intermitte \"intermitte\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,intermitte,0,254;layer \"layer\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,layer,0,254;name_en \"name_en\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,name_en,0,254;name \"name\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,name,0,254;boat \"boat\" true true false 254 Text 0 0,First,#,Waterway_OSM_YGN,boat,0,254;pointid \"pointid\" true true false 4 Long 0 0,First,#,D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\River_Network_13_AnalysedPoints_YGN,pointid,-1,-1;grid_code \"grid_code\" true true false 4 Float 0 0,Sum,#,D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\River_Network_13_AnalysedPoints_YGN,grid_code,-1,-1"
    Search_Radius = "500 Meters"
    Dissolve_Fields = ["osm_id"]
    Statistics_Fields = [["grid_code", "SUM"]]
    Create_multipart_features = False
    Unsplit_lines = False
    Join_Operation_2_ = "JOIN_ONE_TO_MANY"
    Field_Map_2_ = ""
    Search_Radius_2_ = "10 Meters"
    Field_Name_Existing_or_New_2_ = "Leakage"
    Expression_2_ = "!SUM_grid_code! * !grid_code!"

# %%
# Processing the Membership Function

def HotspotAnalysis():
    
    arcpy.ImportToolbox(r"C:\program files\arcgis\pro\Resources\ArcToolbox\toolboxes\Analysis Tools.tbx")
    
    # Process: Fuzzy Membership (Fuzzy Membership) (sa)
    FuzzyM_11_Population_Density_YGN_2_ = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\FuzzyM_11_Population_Density_YGN"
    Fuzzy_Membership = FuzzyM_11_Population_Density_YGN_2_
    FuzzyM_11_Population_Density_YGN_2_ = arcpy.sa.FuzzyMembership(_1_Population_Density_YGN_tif, Membership_type, "NONE")
    FuzzyM_11_Population_Density_YGN_2_.save(Fuzzy_Membership)


    # Process: Con (Con) (ia)
    LULC_1_Con = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\LULC_1_Con"
    Con = LULC_1_Con
    LULC_1_Con = arcpy.ia.Con(_2_LULC_YGN_tif, _2_LULC_YGN_tif_2_, "", "VALUE = 7")
    LULC_1_Con.save(Con)


    # Process: Fuzzy Membership (6) (Fuzzy Membership) (sa)
    FuzzyM_12_LULC_YGN_2_ = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\FuzzyM_12_LULC_YGN"
    Fuzzy_Membership_6_ = FuzzyM_12_LULC_YGN_2_
    FuzzyM_12_LULC_YGN_2_ = arcpy.sa.FuzzyMembership(LULC_1_Con, Membership_type_6_, "NONE")
    FuzzyM_12_LULC_YGN_2_.save(Fuzzy_Membership_6_)


    # Process: Feature To Point (3) (Feature To Point) (management)
    Conversion_1_Building_Inductrial = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Conversion_1_Building_Inductrial"
    arcpy.management.FeatureToPoint(in_features=_3a_Building_Industrial_YGN, out_feature_class=Conversion_1_Building_Inductrial)

    # Process: Kernel Density (5) (Kernel Density) (sa)
    Conversion_1a_Building_Industrial = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Conversion_1a_Building_Industrial"
    Kernel_Density_5_ = Conversion_1a_Building_Industrial
    Conversion_1a_Building_Industrial = arcpy.sa.KernelDensity(Conversion_1_Building_Inductrial, "NONE", "0.0000900900900900901", None, "SQUARE_MAP_UNITS", "DENSITIES", "PLANAR", "")
    Conversion_1a_Building_Industrial.save(Kernel_Density_5_)


    # Process: Fuzzy Membership (7) (Fuzzy Membership) (sa)
    FuzzyM_1_Building_Industrial_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\FuzzyM_1_Building_Industrial_YGN"
    Fuzzy_Membership_7_ = FuzzyM_1_Building_Industrial_YGN
    FuzzyM_1_Building_Industrial_YGN = arcpy.sa.FuzzyMembership(Conversion_1a_Building_Industrial, Membership_type_7_, "NONE")
    FuzzyM_1_Building_Industrial_YGN.save(Fuzzy_Membership_7_)


    # Process: Feature To Point (2) (Feature To Point) (management)
    Conversion_2_Buildings = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Conversion_2_Buildings"
    arcpy.management.FeatureToPoint(in_features=_3_Building_Footprints_YGN, out_feature_class=Conversion_2_Buildings)

    # Process: Kernel Density (6) (Kernel Density) (sa)
    Conversion_2a_Buildings = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Conversion_2a_Buildings"
    Kernel_Density_6_ = Conversion_2a_Buildings
    Conversion_2a_Buildings = arcpy.sa.KernelDensity(Conversion_2_Buildings, "NONE", "0.0000900900900900901", None, "SQUARE_MAP_UNITS", "DENSITIES", "PLANAR", "")
    Conversion_2a_Buildings.save(Kernel_Density_6_)


    # Process: Fuzzy Membership (8) (Fuzzy Membership) (sa)
    FuzzyM_2_Buildings_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\FuzzyM_2_Buildings_YGN"
    Fuzzy_Membership_8_ = FuzzyM_2_Buildings_YGN
    FuzzyM_2_Buildings_YGN = arcpy.sa.FuzzyMembership(Conversion_2a_Buildings, Membership_type_8_, "NONE")
    FuzzyM_2_Buildings_YGN.save(Fuzzy_Membership_8_)


    # Process: Fuzzy Membership (2) (Fuzzy Membership) (sa)
    FuzzyM_13_Slum_YGN_2_ = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\FuzzyM_13_Slum_YGN"
    Fuzzy_Membership_2_ = FuzzyM_13_Slum_YGN_2_
    FuzzyM_13_Slum_YGN_2_ = arcpy.sa.FuzzyMembership(_4_Slum_YGN_tif, Membership_type_2_, "NONE")
    FuzzyM_13_Slum_YGN_2_.save(Fuzzy_Membership_2_)


    # Process: Feature To Point (Feature To Point) (management)
    Conversion_3_Road_Networks = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Conversion_3_Road_Networks"
    arcpy.management.FeatureToPoint(in_features=_6_Road_Networks_YGN, out_feature_class=Conversion_3_Road_Networks)

    # Process: Euclidean Distance (Euclidean Distance) (sa)
    Conversion_3a_Road_Networks = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Conversion_3a_Road_Networks"
    Euclidean_Distance = Conversion_3a_Road_Networks
    Output_direction_raster = ""
    Out_back_direction_raster = ""
    Conversion_3a_Road_Networks = arcpy.sa.EucDistance(Conversion_3_Road_Networks, None, "0.0000900900900900901", Output_direction_raster, "PLANAR", "", Out_back_direction_raster)
    Conversion_3a_Road_Networks.save(Euclidean_Distance)


    # Process: Fuzzy Membership (9) (Fuzzy Membership) (sa)
    FuzzyM_3_Road_Networks_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\FuzzyM_3_Road_Networks_YGN"
    Fuzzy_Membership_9_ = FuzzyM_3_Road_Networks_YGN
    FuzzyM_3_Road_Networks_YGN = arcpy.sa.FuzzyMembership(Conversion_3a_Road_Networks, Membership_type_9_, "NONE")
    FuzzyM_3_Road_Networks_YGN.save(Fuzzy_Membership_9_)


    # Process: Kernel Density (7) (Kernel Density) (sa)
    Conversion_4_Infrastructure_POI = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Conversion_4_Infrastructure_POI"
    Kernel_Density_7_ = Conversion_4_Infrastructure_POI
    Conversion_4_Infrastructure_POI = arcpy.sa.KernelDensity(_7_Infrastructure_POIs_YGN, "NONE", "0.0000900900900900901", None, "SQUARE_MAP_UNITS", "DENSITIES", "PLANAR", "")
    Conversion_4_Infrastructure_POI.save(Kernel_Density_7_)


    # Process: Fuzzy Membership (10) (Fuzzy Membership) (sa)
    FuzzyM_4_Infrastructure_POI_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\FuzzyM_4_Infrastructure_POI_YGN"
    Fuzzy_Membership_10_ = FuzzyM_4_Infrastructure_POI_YGN
    FuzzyM_4_Infrastructure_POI_YGN = arcpy.sa.FuzzyMembership(Conversion_4_Infrastructure_POI, Membership_type_10_, "NONE")
    FuzzyM_4_Infrastructure_POI_YGN.save(Fuzzy_Membership_10_)


    # Process: Fuzzy Membership (3) (Fuzzy Membership) (sa)
    FuzzyM_14_NLRS_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\FuzzyM_14_NLRS_YGN"
    Fuzzy_Membership_3_ = FuzzyM_14_NLRS_YGN
    FuzzyM_14_NLRS_YGN = arcpy.sa.FuzzyMembership(_8_NLRS_YGN_tif, Membership_type_3_, "NONE")
    FuzzyM_14_NLRS_YGN.save(Fuzzy_Membership_3_)


    # Process: Kernel Density (8) (Kernel Density) (sa)
    Conversion_11_PWGeneration = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Conversion_11_PWGeneration"
    Kernel_Density_8_ = Conversion_11_PWGeneration
    Conversion_11_PWGeneration = arcpy.sa.KernelDensity(Population_3_Intersect_Building_YGN_3_, "NONE", Output_cell_size_4_, None, "SQUARE_KILOMETERS", "DENSITIES", "PLANAR", "")
    Conversion_11_PWGeneration.save(Kernel_Density_8_)


    # Process: Fuzzy Membership (4) (Fuzzy Membership) (sa)
    FuzzyM_21_PWGenaration_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\FuzzyM_21_PWGenaration_YGN"
    Fuzzy_Membership_4_ = FuzzyM_21_PWGenaration_YGN
    FuzzyM_21_PWGenaration_YGN = arcpy.sa.FuzzyMembership(Conversion_11_PWGeneration, Membership_type_4_, "NONE")
    FuzzyM_21_PWGenaration_YGN.save(Fuzzy_Membership_4_)

# %%
 # Process: Buffer (Buffer) (analysis)
    FDS_1_Buffer_1km_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\FDS_1_Buffer_1km_YGN"
    arcpy.analysis.Buffer(in_features=_10_Waste_Collection_YGN_2_, out_feature_class=FDS_1_Buffer_1km_YGN, buffer_distance_or_field=Distance_value_or_field_)

    # Process: Clip Raster (2) (Clip Raster) (management)
    FDS_2_Clip_Slum_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\FDS_2_Clip_Slum_YGN"
    arcpy.management.Clip(in_raster=_4_Slum_YGN_tif_2_, rectangle="10686660.1718803 1874979.79489321 10727673.3906528 1931365.7759893", out_raster=FDS_2_Clip_Slum_YGN, in_template_dataset=FDS_1_Buffer_1km_YGN)
    FDS_2_Clip_Slum_YGN = arcpy.Raster(FDS_2_Clip_Slum_YGN)

    # Process: Raster Calculator (6) (Raster Calculator) (ia)
    FDS_3_Slum_PWGeneration_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\FDS_3_Slum_PWGeneration_YGN"
    Raster_Calculator_6_ = FDS_3_Slum_PWGeneration_YGN
    FDS_3_Slum_PWGeneration_YGN =  FDS_2_Clip_Slum_YGN*(0.5*0.2)
    FDS_3_Slum_PWGeneration_YGN.save(Raster_Calculator_6_)


    # Process: Fuzzy Membership (5) (Fuzzy Membership) (sa)
    FuzzyM_22_FinalDisposal_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\FuzzyM_22_FinalDisposal_YGN"
    Fuzzy_Membership_5_ = FuzzyM_22_FinalDisposal_YGN
    FuzzyM_22_FinalDisposal_YGN = arcpy.sa.FuzzyMembership(FDS_3_Slum_PWGeneration_YGN, Membership_type_5_, "NONE")
    FuzzyM_22_FinalDisposal_YGN.save(Fuzzy_Membership_5_)


    # Process: Fuzzy Overlay (Fuzzy Overlay) (sa)
    Fuzzy_Result_5_Static_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Fuzzy_Result_5_Static_YGN"
    Fuzzy_Overlay = Fuzzy_Result_5_Static_YGN
    Fuzzy_Result_5_Static_YGN = arcpy.sa.FuzzyOverlay([FuzzyM_11_Population_Density_YGN_2_, FuzzyM_12_LULC_YGN_2_, FuzzyM_1_Building_Industrial_YGN, FuzzyM_2_Buildings_YGN, FuzzyM_13_Slum_YGN_2_, FuzzyM_3_Road_Networks_YGN, FuzzyM_4_Infrastructure_POI_YGN, FuzzyM_14_NLRS_YGN, FuzzyM_21_PWGenaration_YGN, FuzzyM_22_FinalDisposal_YGN], Overlay_type, 0.9)
    Fuzzy_Result_5_Static_YGN.save(Fuzzy_Overlay)


    # Process: Raster to Point (Raster to Point) (conversion)
    Fuzzy_Result_5_Static_Points_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Fuzzy_Result_5_Static_Points_YGN"
    with arcpy.EnvManager(outputMFlag="Disabled", outputZFlag="Disabled"):
        arcpy.conversion.RasterToPoint(in_raster=Fuzzy_Result_5_Static_YGN, out_point_features=Fuzzy_Result_5_Static_Points_YGN, raster_field="Value")

    # Process: Kernel Density (Kernel Density) (sa)
    Fuzzy_Result_5_Static_Density_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Fuzzy_Result_5_Static_Density_YGN"
    Kernel_Density = Fuzzy_Result_5_Static_Density_YGN
    Fuzzy_Result_5_Static_Density_YGN = arcpy.sa.KernelDensity(Fuzzy_Result_5_Static_Points_YGN, "NONE", Output_cell_size, None, "SQUARE_KILOMETERS", "DENSITIES", "PLANAR", "")
    Fuzzy_Result_5_Static_Density_YGN.save(Kernel_Density)


    # Process: Feature To Point (4) (Feature To Point) (management)
    Conversion_4_Traffic = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Conversion_4_Traffic"
    arcpy.management.FeatureToPoint(in_features=Traffic16_2_Spatial_Join_Road_YGN, out_feature_class=Conversion_4_Traffic)

    # Process: Euclidean Distance (2) (Euclidean Distance) (sa)
    Conversion_3a_Traffic = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Conversion_3a_Traffic"
    Euclidean_Distance_2_ = Conversion_3a_Traffic
    Output_direction_raster_2_ = ""
    Out_back_direction_raster_2_ = ""
    Conversion_3a_Traffic = arcpy.sa.EucDistance(Conversion_4_Traffic, None, "1.44363302724241E-03", Output_direction_raster_2_, "PLANAR", "", Out_back_direction_raster_2_)
    Conversion_3a_Traffic.save(Euclidean_Distance_2_)


    # Process: Fuzzy Membership (16) (Fuzzy Membership) (sa)
    FuzzyM_16a_Traffic_Trial_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\FuzzyM_16a_Traffic_Trial_YGN"
    Fuzzy_Membership_16_ = FuzzyM_16a_Traffic_Trial_YGN
    FuzzyM_16a_Traffic_Trial_YGN = arcpy.sa.FuzzyMembership(Conversion_3a_Traffic, Membership_type_11_, "NONE")
    FuzzyM_16a_Traffic_Trial_YGN.save(Fuzzy_Membership_16_)


    # Process: Kernel Density (9) (Kernel Density) (sa)
    Conversion_7_Artificial_Barrier = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Conversion_7_Artificial_Barrier"
    Kernel_Density_9_ = Conversion_7_Artificial_Barrier
    Conversion_7_Artificial_Barrier = arcpy.sa.KernelDensity(Artificial_Barrier, Population_field_2_, "0.0000900900900900901", None, "SQUARE_MAP_UNITS", "DENSITIES", "PLANAR", "")
    Conversion_7_Artificial_Barrier.save(Kernel_Density_9_)


    # Process: Fuzzy Membership (13) (Fuzzy Membership) (sa)
    FuzzyM_7_Artificial_Barriers_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\FuzzyM_7_Artificial_Barriers_YGN"
    Fuzzy_Membership_13_ = FuzzyM_7_Artificial_Barriers_YGN
    FuzzyM_7_Artificial_Barriers_YGN = arcpy.sa.FuzzyMembership(Conversion_7_Artificial_Barrier, Membership_type_13_, "NONE")
    FuzzyM_7_Artificial_Barriers_YGN.save(Fuzzy_Membership_13_)


    # Process: Kernel Density (10) (Kernel Density) (sa)
    Conversion_8_Littering_Spots = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Conversion_8_Littering_Spots"
    Kernel_Density_10_ = Conversion_8_Littering_Spots
    Conversion_8_Littering_Spots = arcpy.sa.KernelDensity(Littering_Spot, Population_field_3_, "0.0000900900900900901", None, "SQUARE_MAP_UNITS", "DENSITIES", "PLANAR", "")
    Conversion_8_Littering_Spots.save(Kernel_Density_10_)


    # Process: Fuzzy Membership (14) (Fuzzy Membership) (sa)
    FuzzyM_8_Littering_Spots_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\FuzzyM_8_Littering_Spots_YGN"
    Fuzzy_Membership_14_ = FuzzyM_8_Littering_Spots_YGN
    FuzzyM_8_Littering_Spots_YGN = arcpy.sa.FuzzyMembership(Conversion_8_Littering_Spots, Membership_type_14_, "NONE")
    FuzzyM_8_Littering_Spots_YGN.save(Fuzzy_Membership_14_)


    # Process: Kernel Density (11) (Kernel Density) (sa)
    Conversion_9_Uncontrol_Dumpsites = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Conversion_9_Uncontrol_Dumpsites"
    Kernel_Density_11_ = Conversion_9_Uncontrol_Dumpsites
    Conversion_9_Uncontrol_Dumpsites = arcpy.sa.KernelDensity(Uncontrol_Dumpsite, Population_field_4_, "0.0000900900900900901", None, "SQUARE_MAP_UNITS", "DENSITIES", "PLANAR", "")
    Conversion_9_Uncontrol_Dumpsites.save(Kernel_Density_11_)


    # Process: Fuzzy Membership (15) (Fuzzy Membership) (sa)
    FuzzyM_9_Uncontrol_Dumpsites_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\FuzzyM_9_Uncontrol_Dumpsites_YGN"
    Fuzzy_Membership_15_ = FuzzyM_9_Uncontrol_Dumpsites_YGN
    FuzzyM_9_Uncontrol_Dumpsites_YGN = arcpy.sa.FuzzyMembership(Conversion_9_Uncontrol_Dumpsites, Membership_type_15_, "NONE")
    FuzzyM_9_Uncontrol_Dumpsites_YGN.save(Fuzzy_Membership_15_)


    # Process: Fuzzy Overlay (2) (Fuzzy Overlay) (sa)
    Fuzzy_Result_6_Dynamic_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Fuzzy_Result_6_Dynamic_YGN"
    Fuzzy_Overlay_2_ = Fuzzy_Result_6_Dynamic_YGN
    Fuzzy_Result_6_Dynamic_YGN = arcpy.sa.FuzzyOverlay([Fuzzy_Result_5_Static_YGN, FuzzyM_16a_Traffic_Trial_YGN, FuzzyM_7_Artificial_Barriers_YGN, FuzzyM_8_Littering_Spots_YGN, FuzzyM_9_Uncontrol_Dumpsites_YGN], Overlay_type_2_, 0.9)
    Fuzzy_Result_6_Dynamic_YGN.save(Fuzzy_Overlay_2_)


    # Process: Raster to Point (2) (Raster to Point) (conversion)
    Fuzzy_Result_6_Dynamic_Points_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Fuzzy_Result_6_Dynamic_Points_YGN"
    with arcpy.EnvManager(outputMFlag="Disabled", outputZFlag="Disabled"):
        arcpy.conversion.RasterToPoint(in_raster=Fuzzy_Result_6_Dynamic_YGN, out_point_features=Fuzzy_Result_6_Dynamic_Points_YGN)

    # Process: Kernel Density (2) (Kernel Density) (sa)
    Fuzzy_Result_6_Dynamic_Density_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Fuzzy_Result_6_Dynamic_Density_YGN"
    Kernel_Density_2_ = Fuzzy_Result_6_Dynamic_Density_YGN
    Fuzzy_Result_6_Dynamic_Density_YGN = arcpy.sa.KernelDensity(Fuzzy_Result_6_Dynamic_Points_YGN, "NONE", Output_cell_size_2_, None, "SQUARE_KILOMETERS", "DENSITIES", "PLANAR", "")
    Fuzzy_Result_6_Dynamic_Density_YGN.save(Kernel_Density_2_)


    # Process: Euclidean Distance (3) (Euclidean Distance) (sa)
    Conversion_10_River_Network = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Conversion_10_River_Network"
    Euclidean_Distance_3_ = Conversion_10_River_Network
    Output_direction_raster_3_ = ""
    Out_back_direction_raster_3_ = ""
    Conversion_10_River_Network = arcpy.sa.EucDistance(River_Network_3_Merge_YGN, None, "1.46769980969839E-03", Output_direction_raster_3_, "PLANAR", "", Out_back_direction_raster_3_)
    Conversion_10_River_Network.save(Euclidean_Distance_3_)


    # Process: Fuzzy Membership (11) (Fuzzy Membership) (sa)
    FuzzyM_19_River_Network_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\FuzzyM_19_River_Network_YGN"
    Fuzzy_Membership_11_ = FuzzyM_19_River_Network_YGN
    FuzzyM_19_River_Network_YGN = arcpy.sa.FuzzyMembership(Conversion_10_River_Network, Membership_type_12_, "NONE")
    FuzzyM_19_River_Network_YGN.save(Fuzzy_Membership_11_)


    # Process: Slope (Slope) (sa)
    Conversion_SRTM_1_Slope = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Conversion_SRTM_1_Slope"
    Slope = Conversion_SRTM_1_Slope
    Conversion_SRTM_1_Slope = arcpy.sa.Slope(SRTM_10_Clip_VillageTractsSq_YGN, "DEGREE", 1, "PLANAR", "METER", "GPU_THEN_CPU")
    Conversion_SRTM_1_Slope.save(Slope)


    # Process: Fuzzy Membership (12) (Fuzzy Membership) (sa)
    FuzzyM_10_Slope_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\FuzzyM_10_Slope_YGN"
    Fuzzy_Membership_12_ = FuzzyM_10_Slope_YGN
    FuzzyM_10_Slope_YGN = arcpy.sa.FuzzyMembership(Conversion_SRTM_1_Slope, Membership_type_16_, "NONE")
    FuzzyM_10_Slope_YGN.save(Fuzzy_Membership_12_)


    # Process: Clip Raster (3) (Clip Raster) (management)
    CHIRPS_0102_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\CHIRPS_0102_YGN"
    arcpy.management.Clip(in_raster=chirps_v2_0_2022_0102_tiff, rectangle=YCDC_Bounding_Box, out_raster=CHIRPS_0102_YGN)
    CHIRPS_0102_YGN = arcpy.Raster(CHIRPS_0102_YGN)

    # Process: Int (Int) (ia)
    CHIRPS_1_Int_0102_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\CHIRPS_1_Int_0102_YGN"
    Int = CHIRPS_1_Int_0102_YGN
    CHIRPS_1_Int_0102_YGN = arcpy.ia.Int(CHIRPS_0102_YGN)
    CHIRPS_1_Int_0102_YGN.save(Int)


    # Process: Raster to Polygon (Raster to Polygon) (conversion)
    CHIRPS_2_Pol_0102_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\CHIRPS_2_Pol_0102_YGN"
    with arcpy.EnvManager(outputMFlag="Disabled", outputZFlag="Disabled"):
        arcpy.conversion.RasterToPolygon(in_raster=CHIRPS_1_Int_0102_YGN, out_polygon_features=CHIRPS_2_Pol_0102_YGN, create_multipart_features="MULTIPLE_OUTER_PART")

    # Process: Create Fishnet (Create Fishnet) (management)
    CHIRPS_3_Fishnet_0102_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\CHIRPS_3_Fishnet_0102_YGN"
    CHIRPS_3_Fishnet_0102_YGN_label = arcpy.management.CreateFishnet(out_feature_class=CHIRPS_3_Fishnet_0102_YGN, origin_coord="95.9500041119754 16.6999995037914", y_axis_coord="95.9500041119754 26.6999995037914", cell_width=2.7027027027027E-04, cell_height=2.7027027027027E-04, number_rows=None, number_columns=None, labels="NO_LABELS", template=CHIRPS_2_Pol_0102_YGN, geometry_type="POLYGON")[0]

    # Process: Clip Raster (4) (Clip Raster) (management)
    CHIRPS_0203_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\CHIRPS_0203_YGN"
    arcpy.management.Clip(in_raster=chirps_v2_0_2022_0203_tiff, rectangle=YCDC_Bounding_Box, out_raster=CHIRPS_0203_YGN)
    CHIRPS_0203_YGN = arcpy.Raster(CHIRPS_0203_YGN)

    # Process: Clip Raster (5) (Clip Raster) (management)
    CHIRPS_0304_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\CHIRPS_0304_YGN"
    arcpy.management.Clip(in_raster=chirps_v2_0_2022_0304_tiff, rectangle=YCDC_Bounding_Box, out_raster=CHIRPS_0304_YGN)
    CHIRPS_0304_YGN = arcpy.Raster(CHIRPS_0304_YGN)

    # Process: Clip Raster (6) (Clip Raster) (management)
    CHIRPS_0405_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\CHIRPS_0405_YGN"
    arcpy.management.Clip(in_raster=chirps_v2_0_2022_0405_tiff, rectangle=YCDC_Bounding_Box, out_raster=CHIRPS_0405_YGN)
    CHIRPS_0405_YGN = arcpy.Raster(CHIRPS_0405_YGN)

    # Process: Clip Raster (7) (Clip Raster) (management)
    CHIRPS_0506_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\CHIRPS_0506_YGN"
    arcpy.management.Clip(in_raster=chirps_v2_0_2022_0506_tiff, rectangle=YCDC_Bounding_Box, out_raster=CHIRPS_0506_YGN)
    CHIRPS_0506_YGN = arcpy.Raster(CHIRPS_0506_YGN)

    # Process: Clip Raster (8) (Clip Raster) (management)
    CHIRPS_0607_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\CHIRPS_0607_YGN"
    arcpy.management.Clip(in_raster=chirps_v2_0_2022_0607_tiff, rectangle=YCDC_Bounding_Box, out_raster=CHIRPS_0607_YGN)
    CHIRPS_0607_YGN = arcpy.Raster(CHIRPS_0607_YGN)

    # Process: Clip Raster (9) (Clip Raster) (management)
    CHIRPS_0708_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\CHIRPS_0708_YGN"
    arcpy.management.Clip(in_raster=chirps_v2_0_2022_0708_tiff, rectangle=YCDC_Bounding_Box, out_raster=CHIRPS_0708_YGN)
    CHIRPS_0708_YGN = arcpy.Raster(CHIRPS_0708_YGN)

    # Process: Clip Raster (10) (Clip Raster) (management)
    CHIRPS_0809_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\CHIRPS_0809_YGN"
    arcpy.management.Clip(in_raster=chirps_v2_0_2022_0809_tiff, rectangle=YCDC_Bounding_Box, out_raster=CHIRPS_0809_YGN)
    CHIRPS_0809_YGN = arcpy.Raster(CHIRPS_0809_YGN)

    # Process: Clip Raster (11) (Clip Raster) (management)
    CHIRPS_0910_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\CHIRPS_0910_YGN"
    arcpy.management.Clip(in_raster=chirps_v2_0_2022_0910_tiff, rectangle=YCDC_Bounding_Box, out_raster=CHIRPS_0910_YGN)
    CHIRPS_0910_YGN = arcpy.Raster(CHIRPS_0910_YGN)

    # Process: Clip Raster (12) (Clip Raster) (management)
    CHIRPS_1011_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\CHIRPS_1011_YGN"
    arcpy.management.Clip(in_raster=chirps_v2_0_2022_1011_tiff, rectangle=YCDC_Bounding_Box, out_raster=CHIRPS_1011_YGN)
    CHIRPS_1011_YGN = arcpy.Raster(CHIRPS_1011_YGN)

    # Process: Clip Raster (13) (Clip Raster) (management)
    CHIRPS_1112_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\CHIRPS_1112_YGN"
    arcpy.management.Clip(in_raster=chirps_v2_0_2022_1112_tiff, rectangle=YCDC_Bounding_Box, out_raster=CHIRPS_1112_YGN)
    CHIRPS_1112_YGN = arcpy.Raster(CHIRPS_1112_YGN)

    # Process: Raster Calculator (7) (Raster Calculator) (ia)
    CHIRPS_1_Add_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\CHIRPS_1_Add_YGN"
    Raster_Calculator_7_ = CHIRPS_1_Add_YGN
    CHIRPS_1_Add_YGN =  CHIRPS_0102_YGN + CHIRPS_0203_YGN + CHIRPS_0304_YGN + CHIRPS_0405_YGN + CHIRPS_0506_YGN + CHIRPS_0607_YGN + CHIRPS_0708_YGN + CHIRPS_0809_YGN + CHIRPS_0910_YGN + CHIRPS_1011_YGN + CHIRPS_1112_YGN
    CHIRPS_1_Add_YGN.save(Raster_Calculator_7_)


    # Process: Zonal Statistics (2) (Zonal Statistics) (sa)
    CHIRPS_2_Zonal_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\CHIRPS_2_Zonal_YGN"
    Zonal_Statistics_2_ = CHIRPS_2_Zonal_YGN
    CHIRPS_2_Zonal_YGN = arcpy.sa.ZonalStatistics(CHIRPS_3_Fishnet_0102_YGN, "OID", CHIRPS_1_Add_YGN, Statistics_Type_2_, "DATA", "CURRENT_SLICE", 90, "AUTO_DETECT", "ARITHMETIC", 360)
    CHIRPS_2_Zonal_YGN.save(Zonal_Statistics_2_)


    # Process: Resample (Resample) (management)
    CHIRPS_4_Resample_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\CHIRPS_4_Resample_YGN"
    arcpy.management.Resample(in_raster=CHIRPS_2_Zonal_YGN, out_raster=CHIRPS_4_Resample_YGN, cell_size=Output_Cell_Size_5_)
    CHIRPS_4_Resample_YGN = arcpy.Raster(CHIRPS_4_Resample_YGN)

    # Process: Fuzzy Membership (17) (Fuzzy Membership) (sa)
    FuzzyM_18_AnnualRainfall_YGN_2_ = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\FuzzyM_18_AnnualRainfall_YGN"
    Fuzzy_Membership_17_ = FuzzyM_18_AnnualRainfall_YGN_2_
    FuzzyM_18_AnnualRainfall_YGN_2_ = arcpy.sa.FuzzyMembership(CHIRPS_4_Resample_YGN, Membership_type_17_, "NONE")
    FuzzyM_18_AnnualRainfall_YGN_2_.save(Fuzzy_Membership_17_)


    # Process: Raster to Polygon (2) (Raster to Polygon) (conversion)
    FloodDecade_4_Conversion_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\FloodDecade_4_Conversion_YGN"
    with arcpy.EnvManager(outputMFlag="Disabled", outputZFlag="Disabled"):
        arcpy.conversion.RasterToPolygon(in_raster=FloodDecade_3_RasterLayer_Band1_YGN, out_polygon_features=FloodDecade_4_Conversion_YGN)

    # Process: Union (Union) (analysis)
    FloodCompare_1_Union_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\FloodCompare_1_Union_YGN"
    arcpy.analysis.Union(in_features=[[FloodDecade_4_Conversion_YGN, ""], [FloodPost_3_Clip_YGN, ""]], out_feature_class=FloodCompare_1_Union_YGN, join_attributes="NO_FID")

    # Process: Polygon to Raster (Polygon to Raster) (conversion)
    FloodCompare_2_Conversions_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\FloodCompare_2_Conversions_YGN"
    arcpy.conversion.PolygonToRaster(in_features=FloodCompare_1_Union_YGN, value_field=Value_field, out_rasterdataset=FloodCompare_2_Conversions_YGN, cellsize=Cellsize)

    # Process: Fuzzy Membership (18) (Fuzzy Membership) (sa)
    FuzzyM_20_Soil_Erosivity_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\FuzzyM_20_Soil_Erosivity_YGN"
    Fuzzy_Membership_18_ = FuzzyM_20_Soil_Erosivity_YGN
    FuzzyM_20_Soil_Erosivity_YGN = arcpy.sa.FuzzyMembership(SoilErosivity_1_Clip_Raster_YGN, Membership_type_18_, "NONE")
    FuzzyM_20_Soil_Erosivity_YGN.save(Fuzzy_Membership_18_)


    # Process: Fuzzy Membership (19) (Fuzzy Membership) (sa)
    FuzzyM_15_Drainage_Morphometry_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\FuzzyM_15_Drainage_Morphometry_YGN"
    Fuzzy_Membership_19_ = FuzzyM_15_Drainage_Morphometry_YGN
    FuzzyM_15_Drainage_Morphometry_YGN = arcpy.sa.FuzzyMembership(Morphometric_3_Weighted_Clip_YCDC_YGN, Membership_type_19_, "NONE")
    FuzzyM_15_Drainage_Morphometry_YGN.save(Fuzzy_Membership_19_)


    # Process: Fuzzy Overlay (3) (Fuzzy Overlay) (sa)
    Fuzzy_Result_7_Natural_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Fuzzy_Result_7_Natural_YGN"
    Fuzzy_Overlay_3_ = Fuzzy_Result_7_Natural_YGN
    Fuzzy_Result_7_Natural_YGN = arcpy.sa.FuzzyOverlay([Fuzzy_Result_6_Dynamic_YGN, FuzzyM_19_River_Network_YGN, FuzzyM_10_Slope_YGN, FuzzyM_18_AnnualRainfall_YGN_2_, FloodCompare_2_Conversions_YGN, FuzzyM_20_Soil_Erosivity_YGN, FuzzyM_15_Drainage_Morphometry_YGN], Overlay_type_3_, 0.9)
    Fuzzy_Result_7_Natural_YGN.save(Fuzzy_Overlay_3_)


    # Process: Raster to Point (3) (Raster to Point) (conversion)
    Fuzzy_Result_7_Natural_Points_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Fuzzy_Result_7_Natural_Points_YGN"
    with arcpy.EnvManager(outputMFlag="Disabled", outputZFlag="Disabled"):
        arcpy.conversion.RasterToPoint(in_raster=Fuzzy_Result_7_Natural_YGN, out_point_features=Fuzzy_Result_7_Natural_Points_YGN)

    # Process: Kernel Density (3) (Kernel Density) (sa)
    Fuzzy_Result_7_Natural_Density_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Fuzzy_Result_7_Natural_Density_YGN"
    Kernel_Density_3_ = Fuzzy_Result_7_Natural_Density_YGN
    Fuzzy_Result_7_Natural_Density_YGN = arcpy.sa.KernelDensity(Fuzzy_Result_7_Natural_Points_YGN, "NONE", "64.6039798764288", None, "SQUARE_KILOMETERS", "DENSITIES", "PLANAR", "")
    Fuzzy_Result_7_Natural_Density_YGN.save(Kernel_Density_3_)


    # Process: Zonal Statistics (Zonal Statistics) (ia)
    Leakage_1_Zonal_Sum_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Leakage_1_Zonal_Sum_YGN"
    Zonal_Statistics = Leakage_1_Zonal_Sum_YGN
    Leakage_1_Zonal_Sum_YGN = arcpy.ia.ZonalStatistics(Dataset_Static_5_VT_Boundaries_YGN, Zone_Field, Fuzzy_Result_7_Natural_Density_YGN, Statistics_Type, "DATA", "CURRENT_SLICE", 90, "AUTO_DETECT", "ARITHMETIC", 360)
    Leakage_1_Zonal_Sum_YGN.save(Zonal_Statistics)


    # Process: Raster Calculator (Raster Calculator) (ia)
    Leakage_2_Weight_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Leakage_2_Weight_YGN"
    Raster_Calculator = Leakage_2_Weight_YGN
    Leakage_2_Weight_YGN =  Fuzzy_Result_7_Natural_Density_YGN / Leakage_1_Zonal_Sum_YGN
    Leakage_2_Weight_YGN.save(Raster_Calculator)


    # Process: Raster Calculator (2) (Raster Calculator) (ia)
    Leakage_3_Land_Leakage_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Leakage_3_Land_Leakage_YGN"
    Raster_Calculator_2_ = Leakage_3_Land_Leakage_YGN
    Leakage_3_Land_Leakage_YGN =  Leakage_2_Weight_YGN*7064
    Leakage_3_Land_Leakage_YGN.save(Raster_Calculator_2_)


    # Process: Raster Calculator (3) (Raster Calculator) (ia)
    Leakage_3_Water_Leakage_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Leakage_3_Water_Leakage_YGN"
    Raster_Calculator_3_ = Leakage_3_Water_Leakage_YGN
    Leakage_3_Water_Leakage_YGN =  Leakage_2_Weight_YGN *5162
    Leakage_3_Water_Leakage_YGN.save(Raster_Calculator_3_)


    # Process: Raster Calculator (4) (Raster Calculator) (ia)
    Leakage_4_Weighted_Leakage_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Leakage_4_Weighted_Leakage_YGN"
    Raster_Calculator_4_ = Leakage_4_Weighted_Leakage_YGN
    Leakage_4_Weighted_Leakage_YGN = (Leakage_3_Land_Leakage_YGN*0.8)+( Leakage_3_Water_Leakage_YGN*0.2)
    Leakage_4_Weighted_Leakage_YGN.save(Raster_Calculator_4_)


    # Process: Raster to Point (4) (Raster to Point) (conversion)
    Leakage_5_Points_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Leakage_5_Points_YGN"
    with arcpy.EnvManager(outputMFlag="Disabled", outputZFlag="Disabled"):
        arcpy.conversion.RasterToPoint(in_raster=Leakage_4_Weighted_Leakage_YGN, out_point_features=Leakage_5_Points_YGN)

    # Process: Kernel Density (4) (Kernel Density) (sa)
    Leakage_6_Density_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Leakage_6_Density_YGN"
    Kernel_Density_4_ = Leakage_6_Density_YGN
    Leakage_6_Density_YGN = arcpy.sa.KernelDensity(Leakage_5_Points_YGN, Population_field, Output_cell_size_3_, None, "SQUARE_KILOMETERS", "DENSITIES", "PLANAR", "")
    Leakage_6_Density_YGN.save(Kernel_Density_4_)


    # Process: Clip Raster (Clip Raster) (management)
    Population_1_Clip_Settlement_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Population_1_Clip_Settlement_YGN"
    arcpy.management.Clip(in_raster=_1_Population_Density_YGN_tif, rectangle="10686733.6536407 1874947.30106643 10726984.5101733 1930767.09894946", out_raster=Population_1_Clip_Settlement_YGN, in_template_dataset=_3_Building_Footprints_YGN)
    Population_1_Clip_Settlement_YGN = arcpy.Raster(Population_1_Clip_Settlement_YGN)

    # Process: Raster to Point (5) (Raster to Point) (conversion)
    Population_2_Points_Settlement_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Population_2_Points_Settlement_YGN"
    with arcpy.EnvManager(outputMFlag="Disabled", outputZFlag="Disabled"):
        arcpy.conversion.RasterToPoint(in_raster=Population_1_Clip_Settlement_YGN, out_point_features=Population_2_Points_Settlement_YGN, raster_field=Field)

    # Process: Calculate Field (Calculate Field) (management)
    Updated_Input_Table = arcpy.management.CalculateField(in_table=Population_2_Points_Settlement_YGN, field=Field_Name_Existing_or_New_, expression=Expression)[0]

    # Process: Intersect (4) (Intersect) (analysis)
    Population_3_Intersect_Building_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Population_3_Intersect_Building_YGN"
    arcpy.analysis.Intersect(in_features=[[Updated_Input_Table, ""], [_3_Building_Footprints_YGN, ""]], out_feature_class=Population_3_Intersect_Building_YGN)

    # Process: Raster Calculator (5) (Raster Calculator) (ia)
    FDS_3_Slum_PWLeakage_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\FDS_3_Slum_PWLeakage_YGN"
    Raster_Calculator_5_ = FDS_3_Slum_PWLeakage_YGN
    FDS_3_Slum_PWLeakage_YGN =  FDS_2_Clip_Slum_YGN*1.28
    FDS_3_Slum_PWLeakage_YGN.save(Raster_Calculator_5_)


    # Process: Clip Raster (14) (Clip Raster) (management)
    River_Network_9_Morphometry_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\River_Network_9_Morphometry_YGN"
    arcpy.management.Clip(in_raster=FuzzyM_15_Drainage_Morphometry_YGN_2_, rectangle="10682564.7841261 1889305.87338879 10730559.1571751 1931998.295872", out_raster=River_Network_9_Morphometry_YGN, in_template_dataset=River_Network_3_Merge_YGN_2_, clipping_geometry=Use_Input_Features_for_Clipping_Geometry)
    River_Network_9_Morphometry_YGN = arcpy.Raster(River_Network_9_Morphometry_YGN)

    # Process: Zonal Statistics (3) (Zonal Statistics) (sa)
    River_Network_10_SumMorpho_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\River_Network_10_SumMorpho_YGN"
    Zonal_Statistics_3_ = River_Network_10_SumMorpho_YGN
    River_Network_10_SumMorpho_YGN = arcpy.sa.ZonalStatistics(River_Network_3_Merge_YGN_2_, Zone_Field_2_, River_Network_9_Morphometry_YGN, Statistics_Type_3_, "DATA", "CURRENT_SLICE", 90, "AUTO_DETECT", "ARITHMETIC", 360)
    River_Network_10_SumMorpho_YGN.save(Zonal_Statistics_3_)


    # Process: Raster Calculator (8) (Raster Calculator) (ia)
    River_Network_11_WeightedMorpho_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\River_Network_11_WeightedMorpho_YGN"
    Raster_Calculator_8_ = River_Network_11_WeightedMorpho_YGN
    River_Network_11_WeightedMorpho_YGN =  River_Network_9_Morphometry_YGN / River_Network_10_SumMorpho_YGN
    River_Network_11_WeightedMorpho_YGN.save(Raster_Calculator_8_)


    # Process: Multiple Ring Buffer (Multiple Ring Buffer) (analysis)
    River_Network_4_BufferZone_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\River_Network_4_BufferZone_YGN"
    arcpy.analysis.MultipleRingBuffer(Input_Features=River_Network_3_Merge_YGN_2_, Output_Feature_class=River_Network_4_BufferZone_YGN, Distances=Distances, Buffer_Unit=Distance_Unit, Method="GEODESIC")

    # Process: Feature to Raster (Feature to Raster) (conversion)
    River_Network_5_Zone_Raster_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\River_Network_5_Zone_Raster_YGN"
    arcpy.conversion.FeatureToRaster(in_features=River_Network_4_BufferZone_YGN, field=Field_2_, out_raster=River_Network_5_Zone_Raster_YGN, cell_size=Output_cell_size_6_)
    River_Network_5_Zone_Raster_YGN = arcpy.Raster(River_Network_5_Zone_Raster_YGN)

    # Process: Fuzzy Membership (20) (Fuzzy Membership) (sa)
    River_Network_6_Fuzzy_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\River_Network_6_Fuzzy_YGN"
    Fuzzy_Membership_20_ = River_Network_6_Fuzzy_YGN
    River_Network_6_Fuzzy_YGN = arcpy.sa.FuzzyMembership(River_Network_5_Zone_Raster_YGN, Membership_type_20_, "NONE")
    River_Network_6_Fuzzy_YGN.save(Fuzzy_Membership_20_)


    # Process: Zonal Statistics (4) (Zonal Statistics) (sa)
    River_Network_7_Sum_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\River_Network_7_Sum_YGN"
    Zonal_Statistics_4_ = River_Network_7_Sum_YGN
    River_Network_7_Sum_YGN = arcpy.sa.ZonalStatistics(River_Network_3_Merge_YGN_2_, Zone_Field_3_, River_Network_6_Fuzzy_YGN, Statistics_Type_4_, "DATA", "CURRENT_SLICE", 90, "AUTO_DETECT", "ARITHMETIC", 360)
    River_Network_7_Sum_YGN.save(Zonal_Statistics_4_)


    # Process: Raster Calculator (9) (Raster Calculator) (ia)
    River_Network_8_Weighted_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\River_Network_8_Weighted_YGN"
    Raster_Calculator_9_ = River_Network_8_Weighted_YGN
    River_Network_8_Weighted_YGN =  River_Network_6_Fuzzy_YGN / River_Network_7_Sum_YGN
    River_Network_8_Weighted_YGN.save(Raster_Calculator_9_)


    # Process: Raster Calculator (10) (Raster Calculator) (ia)
    River_Network_12_Analysed_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\River_Network_12_Analysed_YGN"
    Raster_Calculator_10_ = River_Network_12_Analysed_YGN
    River_Network_12_Analysed_YGN = ( River_Network_11_WeightedMorpho_YGN + River_Network_8_Weighted_YGN) /2
    River_Network_12_Analysed_YGN.save(Raster_Calculator_10_)


    # Process: Raster to Point (6) (Raster to Point) (conversion)
    River_Network_13_AnalysedPoints_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\River_Network_13_AnalysedPoints_YGN"
    with arcpy.EnvManager(outputMFlag="Disabled", outputZFlag="Disabled"):
        arcpy.conversion.RasterToPoint(in_raster=River_Network_12_Analysed_YGN, out_point_features=River_Network_13_AnalysedPoints_YGN)

    # Process: Kernel Density (12) (Kernel Density) (sa)
    River_Network_14_Density_Leakage_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\River_Network_14_Density_Leakage_YGN"
    Kernel_Density_12_ = River_Network_14_Density_Leakage_YGN
    River_Network_14_Density_Leakage_YGN = arcpy.sa.KernelDensity(River_Network_13_AnalysedPoints_YGN, Population_field_5_, Output_cell_size_7_, None, "SQUARE_KILOMETERS", "DENSITIES", "PLANAR", "")
    River_Network_14_Density_Leakage_YGN.save(Kernel_Density_12_)


    # Process: Spatial Join (Spatial Join) (analysis)
    River_Network_14_Join_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\River_Network_14_Join_YGN"
    arcpy.analysis.SpatialJoin(target_features=Waterway_OSM_YGN, join_features=River_Network_13_AnalysedPoints_YGN, out_feature_class=River_Network_14_Join_YGN, join_operation=Join_Operation, field_mapping=Field_Map, match_option="INTERSECT", search_radius=Search_Radius)

    # Process: Dissolve (Dissolve) (management)
    River_Network_15_Dissolve_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\River_Network_15_Dissolve_YGN"
    arcpy.management.Dissolve(in_features=River_Network_14_Join_YGN, out_feature_class=River_Network_15_Dissolve_YGN, dissolve_field=Dissolve_Fields, statistics_fields=Statistics_Fields, multi_part=Create_multipart_features, unsplit_lines=Unsplit_lines)

    # Process: Spatial Join (2) (Spatial Join) (analysis)
    Leakage_Pathway_1_Join_YGN = "D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Myanmar_Yangon.gdb\\Leakage_Pathway_1_Join_YGN"
    arcpy.analysis.SpatialJoin(target_features=River_Network_15_Dissolve_YGN, join_features=Leakage_5_Points_YGN, out_feature_class=Leakage_Pathway_1_Join_YGN, join_operation=Join_Operation_2_, field_mapping=Field_Map_2_, search_radius=Search_Radius_2_)

    # Process: Calculate Field (2) (Calculate Field) (management)
    Updated_Input_Table_2_ = arcpy.management.CalculateField(in_table=Leakage_Pathway_1_Join_YGN, field=Field_Name_Existing_or_New_2_, expression=Expression_2_)[0]

if __name__ == '__main__':
    # Global Environment settings
    with arcpy.EnvManager(scratchWorkspace="D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Leakage Mapping.gdb", workspace="D:\\Processing\\Transfer ArcGIS\\New Method Leakage Mapping\\Leakage Mapping.gdb"):
        LeakageMapping()

# %%
# Validation B - Adding Sensitivity Analysis
## Reference: Monte Carlo Analyis - Shambaugh 2022

def monaco:
    data = staticData_YGN

# Case input from previous process (LeakageMapping)

case = LeakageMapping

postprocess(case, *run(*preprocess(case)))
siminput = (siminput1, siminput2, ...)
    = preprocess(case)
simoutput = (simoutput1, simoutput2, ...)
    = run(*siminput)
    = run(siminput1, siminput2, ...)
_= postprocess(case, *simoutput)
    = postprocess(case, simoutput1, sioutput2, ...)

case1 = staticResult
case2 = dynamicResult

def example_run(case1, case2):
    dicesum = case1 + case2
    return (dicesum, )

# Added the intervals of probability from static to dynamic 


def example_preprocess(case):
    case1 = case.invals['case1'].val
    case2 = case.invals['case2'].val
    return (case1, case2)

def example_postprocess(case, dicesum):
    case.addOutVal(name='Sum', val=dicesum)
    case.addOutVal(name='Roll ID', val=case.ncase)
    return None

# Include Monaco Analysis

import monaco as mc
from scipy.stats import randint

# dict structure from thrree input fuctions
fcnr = {'run': example_run
       'preprocess': example_preprocess,
        'postprocess': example_postprocess
       }

# initialize the simulations
ndraws = 2048
seed = 123456 #repeated

sim = mc.Sim(name='Dice Roll', ndraws=ndraws, 
             fcns=fcns,
            seed=seed)

# generate the input variable
sim.addInVar(name='case1', dist=randint, distkwargs={'low': 1, 'high': 6+1})
sim.addInVar(name='case2', dist=randint, distkwargs={'low': 1, 'high': 6+1})

sim.runSim()

# calculate statistics
sim.outvars['Sum'].addVarStat('mean')
sim.outvars['Sum'].addVarStat('percentile', {'p':[0.05, 0.95]})

mc.plot(sim.outvars['Sum'])
mc.plot(sim.outvars['Sum'],
       sim.outvars['Roll Number'])

sim.calcSensitives('Sum')
sim.outvars['Sum'].plotSensitivities()
